# %% [markdown]
# <a href="https://colab.research.google.com/github/Tharuna180/PP3-python-/blob/main/labex1blist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1 = ['hello',1,2,'world',1.2]
list2 = ['welcome',5,3,'rainy',3.3]

# %%
print(list1)
print(list2)
# Out:
# ['hello', 1, 2, 'world', 1.2]
# ['welcome', 5, 3, 'rainy', 3.3]

# %%
print(type(list1))
print(type(list2))
# Out:
# <class 'list'>
# <class 'list'>

# %%
list3 = [1,2,3,4,5]
list4 = [1,2,4,3,5]
list3 == list4
# Out:
# False

# %%
list5 = [1,2,3,4,5]
list6 = [1,2,3,4,5]
list5 == list6
# Out:
# True

# %%
print(list1[0])
# Out:
# hello

# %%
print(list5[2:5])
# Out:
# [3, 4, 5]

# %%
print(list2[:])
# Out:
# ['welcome', 5, 3, 'rainy', 3.3]

# %%
print(list2[0:4:1])
# Out:
# ['welcome', 5, 3, 'rainy']

# %%
print(list5[-2])
# Out:
# 4

# %%
print(list5[:-1])
# Out:
# [1, 2, 3, 4]

# %%
list5[2] = 100
print(list5)
# Out:
# [1, 2, 100, 4, 5]

# %%
list2[1:5] = [800]
print(list2)
# Out:
# ['welcome', 800]

# %%
list5[-1] = 40000
print(list5)
# Out:
# [1, 40000]

# %%
list1 * 4
# Out:
# ['hello',
#  1,
#  2,
#  'world',
#  1.2,
#  'hello',
#  1,
#  2,
#  'world',
#  1.2,
#  'hello',
#  1,
#  2,
#  'world',
#  1.2,
#  'hello',
#  1,
#  2,
#  'world',
#  1.2]

# %%
list5 + list6
# Out:
# [1, 800, 1, 800]

# %%
len(list1)
# Out:
# 5

# %%
for i in list1:
  print(i)
# Out:
# hello
# 1
# 2
# world
# 1.2

# %%
print(600 in list5)
# Out:
# False

# %%
a=[]
b=int(input("enter the no.of numbers"))
for i in range(0,b):
    a.append(int(input("enter the numbers")))
for i in a:
             print(i, end="")
# Out:
# enter the no.of numbers3
# enter the numbers10
# enter the numbers20
# enter the numbers30
# 102030

# %%
list1.remove(2)
for i in list1:
  print(i)
# Out:
# hello
# 1
# world
# 1.2

# %%
import copy
old = [[1,2,3],[10,20,30],[100,200,300]]
new = copy.copy(old)
print("old",old)
print("new",new)
# Out:
# old [[1, 2, 3], [10, 20, 30], [100, 200, 300]]
# new [[1, 2, 3], [10, 20, 30], [100, 200, 300]]

# %%
import copy
old = [[1,2,3],[10,20,30],[100,200,300]]
new = copy.copy(old)
print("old",old)
print("new",new)
old.append([4,40,400])
new = copy.copy(old)
print("old",old)
print("new",new)
# Out:
# old [[1, 2, 3], [10, 20, 30], [100, 200, 300]]
# new [[1, 2, 3], [10, 20, 30], [100, 200, 300]]
# old [[1, 2, 3], [10, 20, 30], [100, 200, 300], [4, 40, 400]]
# new [[1, 2, 3], [10, 20, 30], [100, 200, 300], [4, 40, 400]]

# %%
import copy
old = [[1,2,3],[10,20,30],[100,200,300]]
new = copy.copy(old)
old[1][1]=2000
print("old",old)
print("new",new)
# Out:
# old [[1, 2, 3], [10, 2000, 30], [100, 200, 300]]
# new [[1, 2, 3], [10, 2000, 30], [100, 200, 300]]

# %%
import copy
old = [[1,2,3],[10,20,30],[100,200,300]]
new = copy.deepcopy(old)
print("old",old)
print("new",new)
# Out:
# old [[1, 2, 3], [10, 20, 30], [100, 200, 300]]
# new [[1, 2, 3], [10, 20, 30], [100, 200, 300]]

# %%
import copy
old = [[1,2,3],[10,20,30],[100,200,300]]
new = copy.deepcopy(old)
old[1][1]=2000
print("old",old)
print("new",new)
# Out:
# old [[1, 2, 3], [10, 2000, 30], [100, 200, 300]]
# new [[1, 2, 3], [10, 20, 30], [100, 200, 300]]

# %%
l1=['sam','vishnu','ron','david']
l1[4:]=['rose']
print(l1)
# Out:
# ['sam', 'vishnu', 'ron', 'david', 'rose']

# %%
import copy
o1=['sam','vishnu','ron','david','ron']
n1=copy.copy(o1)
print(o1)
print(n1)
o1.append('rossy')
print(o1)
print(n1)
# Out:
# ['sam', 'vishnu', 'ron', 'david', 'ron']
# ['sam', 'vishnu', 'ron', 'david', 'ron']
# ['sam', 'vishnu', 'ron', 'david', 'ron', 'rossy']
# ['sam', 'vishnu', 'ron', 'david', 'ron']

# %%
o=o1.count('ron')
print(o)
# Out:
# 2

# %%
o1=['sam','vishnu','ron','david','ron']
transfer=['ramesh','suresh','vishal','gobi']
a=o1+transfer
print(a)
# Out:
# ['sam', 'vishnu', 'ron', 'david', 'ron', 'ramesh', 'suresh', 'vishal', 'gobi']

# %%
o1=['sam','vishnu','ron','david','ron']
a=o1.index('sam')
print(a)
# Out:
# 0

# %%
o1=['sam','vishnu','ron','david','ron']
o1.insert(2,'vijay')
for i in o1:
  print(i,end=' ')
# Out:
# sam vishnu vijay ron david ron

# %%
o1=['sam','vishnu','ron','david','ron']
a=o1.pop()
for i in o1:
  print(i)
print("removed student:",a)
# Out:
# sam
# vishnu
# ron
# david
# removed student: ron

# %%
o1=['sam','vishnu','ron','david','ron']
o1.remove('david')
for i in o1:
  print(i)
# Out:
# sam
# vishnu
# ron
# ron

# %%
a=['hello','hii']
print(a[::-1])
# Out:
# ['hii', 'hello']

# %%
o1=['sam','vishnu','ron','david','ron']
o1.sort()
print(o1)
# Out:
# ['david', 'ron', 'ron', 'sam', 'vishnu']

# %%
o1.clear()
print(o1)
# Out:
# []
